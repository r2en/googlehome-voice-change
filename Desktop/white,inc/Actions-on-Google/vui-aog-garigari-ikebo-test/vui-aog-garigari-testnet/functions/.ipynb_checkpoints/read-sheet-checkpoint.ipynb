# %%
import pandas as pd

# %%
df = pd.read_csv('sheet.csv')

# %%
df
# Out:
#     収録するすべての台詞をまとめるシートです。\nブルーの箇所：石橋編集部分（0728）\n緑の箇所：北島さん編集部分（0726）\n赤字の箇所：伊東編集部分(0802)\n緑字の箇所：北島編集部分（0802）※推敲部分で修正します\n推敲欄赤字の箇所：北村編集部分(0803)　伊東修正部分(0803)\n→推敲部分で、どうしても気になる箇所があり青文字になっています。備考欄にも質問してます（20,40,86,102、232行目）ご確認後、問題なさそうでしたら無視して、削除してください。（石橋0803）→確認修正しました。(伊東0803)\nFIXの列：伊東編集部分(0806)　※主にトレーニング部分  \
# 0                                                   ID
# 1                                                    0
# 2                                                    1
# 3                                                    2
# 4                                                    3
# 5                                                    4
# 6                                                    5
# 7                                                    6
# 8                                                    7
# 9                                                    8
# 10                                                   9
# 11                                                  10
# ...

# %%
df.drop("Unnamed: 1	", axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5eb8adb8ece7> in <module>()
# ----> 1 df.drop("Unnamed:1", axis=1)
#
# /Users/takayoshi-endo/.anyenv/envs/pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# /Users/takayoshi-endo/.anyenv/envs/pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# ...
